# %%
from utils.functions import precios
import pandas as pd
pd.set_option('max_colwidth', 100)
import numpy as np
import regex as re
import random
import yfinance as yf

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams["figure.figsize"] = (15,6)

# %% [markdown]
# ### Importo DF de sentimiento, y los precios de los activos (librería yfinance)

# %%
import pandas as pd
df_sent = pd.read_csv('data/final_data.csv')

df_sent.tail(5)
# Out:
#            date ticker  \
# 785  2023-02-14   msft
# 225  2023-03-01   tsla
# 250  2023-03-02   goog
# 400  2023-02-16    jnj
# 951  2023-02-27   GC=F
#
#                                                                                                     link  \
# 785  https://finance.yahoo.com//news/prices-are-still-going-up-and-consumers-are-still-spending-morni...
# 225                     https://finance.yahoo.com//news/timeline-elon-musk-missed-targets-110000795.html
# 250                  https://finance.yahoo.com//news/stock-market-news-today-march-2-2023-135533324.html
# 400                  https://finance.yahoo.com//news/early-retirement-portfolio-15-stocks-001129511.html
# 951                        https://finance.yahoo.com//news/canada-stocks-shares-boost-tsx-221058134.html
#
#                                                                                                 articles  \
# 785  This article first appeared in the Morning Brief. Get the Morning Brief sent directly to your in...
# 225  March 1 (Reuters) - Tesla Inc Chief Executive Elon Musk is expected to lay out details of afford...
# 250  Stock futures were mixed on Thursday morning as investors digested more big tech earnings and co...
# 400  In this article, we discuss 15 best dividend stocks for retirement. You can skip our detailed an...
# 951  * TSX ends up 0.2% at 20,260.13 * Uni-Select shares surge 16.6% after takeover deal * Materials ...
#
#                                                                                            spacy_summary  \
# 785  6:00 a.m. ET: NFIB Small Business Optimism, January (91.0 expected, 89.9 during prior month) 8:3...
# 225  March 1 (Reuters) - Tesla Inc Chief Executive Elon Musk is expected to lay out details of afford...
# 250  Tesla (TSLA) shares were also in focus early Thursday, falling as much as 7% after the electric ...
# 400  Last year, I wrote an article on Early Retirement Portfolio: 15 Stocks to Live Off Dividends, wh...
# 951  "The overhang of possibly more interest rate rises is going to cloud market sentiment until eith...
#
#                                                                                         pegasus_one_line  \
# 785                                        Weekly take on events in the world economy and their fallout.
# 225  Musk is expected to unveil details of affordable electric cars. EV maker has said it could build...
# 250  Salesforce beats on earnings, raises share buyback plan. Tesla shares fall as much as 7% in earl...
# 400  Johnson & Johnson, AbbVie are best for retirement stocks. American Power Electric Company is bes...
# 951                                                  Toronto's main stock index closes higher on Monday.
#
#      sentiment
# 785          0
# 225          0
# 250          1
# 400          1
# 951          0

# %%
df_sent.to_csv('data/final_data.csv')

# %%
df_precios = precios(start='2023-02-14',end='2023-03-03',tickers=df_sent.ticker.unique())
df_precios.Date = pd.to_datetime(df_precios.Date)
df_precios.Date.dtypes
# Out:
# ['aapl' 'tsla' 'goog' 'jnj' 'BTC-USD' 'amzn' 'msft' 'GC=F']
# dtype('<M8[ns]')

# %% [markdown]
# ### Comparación palabras medias por artículo en cada paso

# %%
df_sent['Artículos originales'] = df_sent.articles.apply(lambda x: len(x.split(' ')))
df_sent['Artículo resumido'] = df_sent.spacy_summary.apply(lambda x: len(x.split(' ')))
df_sent['En una línea'] = df_sent.pegasus_one_line.apply(lambda x: len(x.split(' ')))

print('Artículos originales :', np.mean(df_sent['Artículos originales']))
print('Artículo resumido :', np.mean(df_sent['Artículo resumido']))
print('En una línea :', np.mean(df_sent['En una línea']))
# Out:
# Artículos originales : 777.289896128423
# Artículo resumido : 227.0462700661001
# En una línea : 14.800755429650614

# %%
sns.barplot(data=df_sent[['Artículos originales','Artículo resumido','En una línea']],palette='magma',errorbar=None)
plt.title('Longitud media de los textos (en palabras)');

# %% [markdown]
# ### Sentiment

# %%
df_sent = pd.read_csv('data/final_data.csv')
df_sent
# Out:
#             date ticker  \
# 0     2023-03-02   aapl
# 1     2023-03-02   aapl
# 2     2023-03-02   aapl
# 3     2023-03-02   aapl
# 4     2023-03-01   aapl
# ...          ...    ...
# 1054  2023-02-17   GC=F
# 1055  2023-02-17   GC=F
# 1056  2023-02-17   GC=F
# 1057  2023-02-17   GC=F
# 1058  2023-02-17   GC=F
#
#                                                                                                      link  \
# 0                         https://finance.yahoo.com//news/mortgage-rates-surge-closer-to-7-170022384.html
# 1                     https://finance.yahoo.com//news/stock-market-news-today-march-2-2023-135533324.html
# 2     https://finance.yahoo.com//news/what-the-end-of-the-great-moderation-era-means-for-investors-mor...
# 3     https://finance.yahoo.com//news/silvergate-stock-crashes-after-company-delays-annual-report-reve...
# 4              https://finance.yahoo.com//news/stock-market-news-live-updates-march-1-2023-124448484.html
# ...                                                                                                   ...
# 1054                    https://finance.yahoo.com//news/natural-gas-price-forecast-natural-164415226.html
# 1055                          https://finance.yahoo.com//news/gold-futures-post-3rd-weekly-150517561.html
# 1056                   https://finance.yahoo.com//news/moneyshow-market-minute-february-17-141500675.html
# 1057                         https://finance.yahoo.com//news/1-investors-pull-cash-classic-132804341.html
# 1058           https://finance.yahoo.com//news/bernstein-sec-tightening-crypto-regulations-101808714.html
#
#                                                                                                  articles  \
# 0     Mortgage rates jumped higher this week, getting even closer to 7% and crushing homebuyer activit...
# 1     Stock futures were mixed on Thursday morning as investors digested more big tech earnings and co...
# 2     This article first appeared in the Morning Brief. Get the Morning Brief sent directly to your in...
# 3     Shares of troubled lender Silvergate (SI) fell as much as 35% Thursday morning after the company...
# 4     U.S. stocks finished mostly lower Wednesday to start March as key manufacturing data offered mix...
# ...                                                                                                   ...
# 1054  Natural gas markets have initially fallen during the trading session on Friday as we continue to...
# 1055  By Barani Krishnan Investing.com - Gold futures posted their third weekly loss while clinging to...
# 1056  Equities tumbled late yesterday, and they’re re-tumbling early today. Gold, silver, and oil are ...
# 1057  (Adds tech flows, recent market moves) LONDON, Feb 17 (Reuters) - Investors turned more cautious...
# 1058  Regulatory action against the Binance USD (BUSD) stablecoin and its issuer Paxos was specific to...
#
#                                                                                             spacy_summary  \
# 0     “We'll find out in the next 30 days if buyers are getting used to higher rates,” Reynolds said, ...
# 1     Tesla (TSLA) shares were also in focus early Thursday, falling as much as 7% after the electric ...
# 2     "I would therefore expect greater inflation volatility, economic volatility, [and] geopolitical ...
# 3     Silvergate shares have collapsed over the last year as the company's entanglements with several ...
# 4     However, Goolsbee, who will be a voter at this year’s policy-setting Federal Open Market Committ...
# ...                                                                                                   ...
# 1054  Stock Markets Continue to Struggle in General, as We Have Seen a Lot of Noise S&P 500 Price Fore...
# 1055  Gold futures posted their third weekly loss while clinging to support at the mid-$1,800 level as...
# 1056  Yesterday’s faceplant was fueled by a January Producer Price Index (PPI) report showing wholesal...
# 1057  BofA Global Research's weekly "Flow Show", released on Friday, showed the largest outflows from ...
# 1058  The custody rule change is currently a proposal, and is favorable for bank-custodians and thus p...
#
#                                                                                          pegasus_one_line  \
# 0                 Real estate broker sees fewer buyers this year. Condo rates hit a 28-year low this week
# 1     Salesforce beats on earnings, raises share buyback plan. Tesla shares fall as much as 7% in earl...
# 2     Sonders sees near-term volatility as key to long-term success. Schwab strategist sees volatility...
# 3                             Here is a guide to the key events in the crypto world in the past 24 hours.
# 4     U.S. vaccine maker leans toward fiscal-hiking campaign. Goolsbee doesn’t comment on Fed’s forwar...
# ...                                                                                                   ...
# 1054                                                  Natural gas markets continue to see lack of demand.
# 1055  bulls try to discern direction amid calls for hikes. U.S. wholesale prices rose most in seven mo...
# 1056                                            Wholesale inflation up 0.7% in March vs est. rise of 0.6%
# 1057                                                     Emerging market funds see outflows for 14th week
# 1058  Bank-custodians should have custody rights, analysts say. Sharp price affected by short covering...
#
#       sentiment
# 0            -1
# 1             1
# 2             1
# 3             0
# 4             0
# ...         ...
# 1054         -1
# 1055          0
# 1056          0
# 1057          0
# 1058          0
#
# [1059 rows x 7 columns]

# %%
df_sent = df_sent[['date','ticker','sentiment']]
df_sent.date = pd.to_datetime(df_sent['date'])
# Filtro artículos por fecha.
df_sent = df_sent[(df_sent['date'] > '2023-02-13' )]
df_sent
# Out:
# C:\Users\Han\AppData\Local\Temp\ipykernel_6712\3620452216.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sent.date = pd.to_datetime(df_sent['date'])
#            date ticker  sentiment
# 0    2023-03-02   aapl         -1
# 1    2023-03-02   aapl          1
# 2    2023-03-02   aapl          1
# 3    2023-03-02   aapl          0
# 4    2023-03-01   aapl          0
# ...         ...    ...        ...
# 1054 2023-02-17   GC=F         -1
# 1055 2023-02-17   GC=F          0
# 1056 2023-02-17   GC=F          0
# 1057 2023-02-17   GC=F          0
# 1058 2023-02-17   GC=F          0
#
# [982 rows x 3 columns]

# %% [markdown]
# ### Combino sentimiento y precio en gráficos de barras

# %%
# Figura y ejes para subplots
num_rows = len(df_sent.ticker.unique())
fig, axs = plt.subplots(num_rows, 1, figsize=(13, 4*num_rows), sharex='col',gridspec_kw={'top': 0.9})
plt.subplots_adjust(hspace=0.5)

for i, tick in enumerate(df_sent.ticker.unique()):
    
    # Sentimiento en el eje Y izquierdo
    ax1 = axs[i]
    sns.lineplot(ax=ax1, data=df_sent[df_sent['ticker'] == tick], y='sentiment', x='date',
                  hue='ticker', palette=['purple'], linewidth=2.5,errorbar=('ci', False),legend=False,label='Sentiment')
    ax1.legend(loc='upper left')

    # Sentimiento en el eje Y izquierdo
    ax2 = ax1.twinx()
    
    # Precio en el eje Y derecho
    sns.lineplot(ax=ax2, data=df_precios[['Date', tick]], y=tick, x='Date', linewidth=2.5,label='Price',errorbar=('ci', False))
    
    # Título y labels para los ejes
    ax1.set_title(tick)
    ax1.set_ylabel('Sentiment')
    ax2.set_ylabel('Price')
axs[num_rows-1].set_xlabel('Date')

# No consigo quitar el padding debajo del título
plt.suptitle('Plot sentimiento y precio')
# Out:
# Text(0.5, 0.98, 'Plot sentimiento y precio')

# %% [markdown]
# ### Stacked bar plot

# %%
df_crosstab = df_sent.copy()
df_crosstab['sentiment'].replace({1:'Positivo',0:'Neutro',-1:'Negativo'},inplace=True)


pd.crosstab(df_crosstab['ticker'], df_crosstab['sentiment']).plot(kind='bar',
                                                                  stacked=True,color=['red','darkgrey','green'],
                                                                  )
plt.title('Distribución Sentimiento en el periodo estudiado')
plt.xlabel('Ticker')
plt.ylabel('Sentiment');

# Lo mismo sin valores neutros

df_no_neutral = df_crosstab.copy()
df_no_neutral = df_no_neutral[df_no_neutral.sentiment != 'Neutro']

pd.crosstab(df_no_neutral['ticker'], df_no_neutral['sentiment']).plot(kind='bar',
                                                                  stacked=True,color=['red','green'],
                                                                  )
plt.title('Distribución Sentimiento (sin valores neutros)')
plt.xlabel('Ticker')
plt.ylabel('Sentiment');

# %% [markdown]
# # Correlación

# %%
# Uso pivot para poder combinar el DF de precios y el de sentiment
df_pivot = pd.pivot_table(df_sent, values='sentiment', index='date', columns='ticker').reset_index().sort_values('date')

# Uso interpolate en lugar de bfill para imputar valores medios entre Nan
df_pivot.iloc[:,1:] = df_pivot.iloc[:,1:].interpolate(axis=1)
# bfill un valor suelto
df_pivot.fillna(method='bfill',inplace=True)
df_pivot.columns += '_sentiment'
df_pivot.head(40)
# Out:
# ticker date_sentiment  BTC-USD_sentiment  GC=F_sentiment  aapl_sentiment  \
# 0          2023-02-14          -0.181818       -0.250000       -0.250000
# 1          2023-02-15          -0.100000       -0.500000       -0.500000
# 2          2023-02-16           0.045455       -0.250000       -0.250000
# 3          2023-02-17           0.100000        0.066667        0.111111
# 4          2023-02-18           0.400000        0.500000        0.250000
# 5          2023-02-19           0.000000       -0.250000        0.000000
# 6          2023-02-20           0.500000       -0.090909        1.000000
# 7          2023-02-21          -0.083333       -0.400000       -0.142857
# 8          2023-02-22          -0.272727       -0.250000        0.000000
# 9          2023-02-23           0.111111        0.157895        0.000000
# 10         2023-02-24          -0.076923        0.000000        0.166667
# 11         2023-02-25          -1.000000       -1.000000        0.250000
# 12         2023-02-26          -0.166667        0.333333        0.416667
# 13         2023-02-27          -0.166667       -0.235294       -0.250000
# 14         2023-02-28          -0.200000       -0.083333       -0.071429
# 15         2023-03-01          -0.285714       -0.058824        0.062500
# 16         2023-03-02           0.100000       -0.166667       -0.083333
#
# ticker  amzn_sentiment  goog_sentiment  jnj_sentiment  msft_sentiment  \
# 0            -0.250000       -0.250000      -0.111111       -0.250000
# 1            -0.500000       -0.500000       0.666667       -0.500000
# 2            -0.250000       -0.250000       0.500000       -0.250000
# 3             0.000000        0.000000       0.000000        0.000000
# 4             0.500000        0.500000       0.000000        0.500000
# 5             0.000000        0.000000       0.000000        0.000000
# 6             1.000000        1.000000       1.000000        1.000000
# 7            -0.100000        0.000000      -0.333333        0.214286
# 8             0.307692        0.080000       0.000000        0.034483
# 9             0.000000       -0.166667      -1.000000       -0.166667
# 10            0.444444       -0.071429       1.000000        0.111111
# 11            0.000000        1.000000       1.000000        1.000000
# 12            0.500000        0.583333       0.666667        0.750000
# 13           -0.125000       -0.125000       0.571429       -0.100000
# 14            0.153846        0.100000       0.000000        0.000000
# 15            0.000000       -0.047619       0.000000       -0.111111
# 16            0.250000        0.272727       0.000000        0.200000
#
# ticker  tsla_sentiment
# 0            -0.250000
# 1            -0.500000
# 2            -0.250000
# 3             0.000000
# 4             0.500000
# 5             0.000000
# 6             1.000000
# 7             0.000000
# 8            -0.500000
# 9            -0.333333
# 10            0.000000
# 11            1.000000
# 12            0.750000
# 13           -0.500000
# 14           -0.052632
# 15            0.063830
# 16           -0.027027

# %%
# Combino los DF para sacar correlación
merged_df = pd.merge(df_pivot, df_precios, right_on='Date',left_on='date_sentiment').drop(columns='Date')
merged_df.head(3)
# Out:
#   date_sentiment  BTC-USD_sentiment  GC=F_sentiment  aapl_sentiment  \
# 0     2023-02-14          -0.181818           -0.25           -0.25
# 1     2023-02-15          -0.100000           -0.50           -0.50
# 2     2023-02-16           0.045455           -0.25           -0.25
#
#    amzn_sentiment  goog_sentiment  jnj_sentiment  msft_sentiment  \
# 0           -0.25           -0.25      -0.111111           -0.25
# 1           -0.50           -0.50       0.666667           -0.50
# 2           -0.25           -0.25       0.500000           -0.25
#
#    tsla_sentiment        aapl        tsla       goog         jnj  \
# 0           -0.25  153.199997  209.250000  94.949997  160.882858
# 1           -0.50  155.330002  214.240005  97.099998  158.231918
# 2           -0.25  153.710007  202.039993  95.779999  157.110001
#
#         BTC-USD        amzn        msft         GC=F
# 0  22220.804688   99.699997  271.490021  1854.000000
# 1  24307.841797  101.160004  269.320007  1834.199951
# 2  23623.474609   98.150002  262.149994  1842.000000

# %%
# Matriz de correlación y heatmap
corr_matrix = merged_df.iloc[:,1:].pct_change().corr()
fig,ax = plt.subplots(figsize=(13,10))
sns.heatmap(corr_matrix, cmap="PiYG", fmt='.2f',annot=True,center=0,cbar_kws={'shrink':.5})
plt.title("Correlation Matrix")
plt.show()
