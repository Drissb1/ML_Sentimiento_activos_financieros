# %%
import pandas as pd
import numpy as np
import regex as re

from transformers import AutoConfig,pipeline,PegasusTokenizer, TFPegasusForConditionalGeneration, BertTokenizer, TFBertModel, AutoTokenizer,AutoModelForSequenceClassification, BertForSequenceClassification
import spacy
# !python -m spacy download en_core_web_trf
from deep_translator import GoogleTranslator

pd.options.display.max_colwidth = 150

# %%
df = pd.read_csv('data/articles_clean.csv')
df.head(3)
# Out:
#          date ticker  \
# 0  2023-03-02   aapl
# 1  2023-03-02   aapl
# 2  2023-03-02   aapl
#
#                                                                                                                         link  \
# 0                                            https://finance.yahoo.com//news/mortgage-rates-surge-closer-to-7-170022384.html
# 1                                        https://finance.yahoo.com//news/stock-market-news-today-march-2-2023-135533324.html
# 2  https://finance.yahoo.com//news/what-the-end-of-the-great-moderation-era-means-for-investors-morning-brief-103057491.html
#
#                                                                                                                                                 articles
# 0  Mortgage rates jumped higher this week, getting even closer to 7% and crushing homebuyer activity, which hit a 28-year low. The average rate on th...
# 1  Stock futures were mixed on Thursday morning as investors digested more big tech earnings and continued to weigh the implications of the recent ba...
# 2  This article first appeared in the Morning Brief. Get the Morning Brief sent directly to your inbox every Monday to Friday by 6:30 a.m. ET. Subscr...

# %% [markdown]
# ### Aplico Spacy sobre los artículos

# %%
def apply_spacy(text):
    nlp = spacy.load('en_core_web_trf')
    nlp.add_pipe('textrank')
    doc = nlp(text)

    spacy_summary = ' '.join([str(sentence) for sentence in doc._.textrank.summary(limit_sentences=8)])
    return spacy_summary

df['spacy_summary'] = df.articles.apply(apply_spacy)
df.to_csv('data/articles_summary.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 9
#       6     spacy_summary = ' '.join([str(sentence) for sentence in doc._.textrank.summary(limit_sentences=8)])
#       7     return spacy_summary
# ----> 9 df['spacy_summary'] = df.articles.apply(apply_spacy)
#      10 df.to_csv('data/articles_summary.csv',index=False)
#
# File ~\.conda\envs\sentiment\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\.conda\envs\sentiment\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\.conda\envs\sentiment\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\.conda\envs\sentiment\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[31], line 2, in apply_spacy(text)
#       1 def apply_spacy(text):
# ----> 2     nlp = spacy.load('en_core_web_trf')
#       3     nlp.add_pipe('textrank')
#       4     doc = nlp(text)
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\util.py:432, in load_model(name, vocab, disable, enable, exclude, config)
#     430     return get_lang_class(name.replace("blank:", ""))()
#     431 if is_package(name):  # installed as package
# --> 432     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     433 if Path(name).exists():  # path to model data directory
#     434     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\util.py:468, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     451 """Load a model from an installed package.
#     452
#     453 name (str): The package name.
#    (...)
#     465 RETURNS (Language): The loaded nlp object.
#     466 """
#     467 cls = importlib.import_module(name)
# --> 468 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~\.conda\envs\sentiment\lib\site-packages\en_core_web_trf\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\util.py:649, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     647 if not model_path.exists():
#     648     raise IOError(Errors.E052.format(path=data_path))
# --> 649 return load_model_from_path(
#     650     data_path,
#     651     vocab=vocab,
#     652     meta=meta,
#     653     disable=disable,
#     654     enable=enable,
#     655     exclude=exclude,
#     656     config=config,
#     657 )
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\util.py:514, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     505 config = load_config(config_path, overrides=overrides)
#     506 nlp = load_model_from_config(
#     507     config,
#     508     vocab=vocab,
#    (...)
#     512     meta=meta,
#     513 )
# --> 514 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\language.py:2125, in Language.from_disk(self, path, exclude, overrides)
#    2122 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2123     # Convert to list here in case exclude is (default) tuple
#    2124     exclude = list(exclude) + ["vocab"]
# -> 2125 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2126 self._path = path  # type: ignore[assignment]
#    2127 self._link_components()
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\util.py:1352, in from_disk(path, readers, exclude)
#    1349 for key, reader in readers.items():
#    1350     # Split to support file names like meta.json
#    1351     if key.split(".")[0] not in exclude:
# -> 1352         reader(path / key)
#    1353 return path
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\language.py:2119, in Language.from_disk.<locals>.<lambda>(p, proc)
#    2117     if not hasattr(proc, "from_disk"):
#    2118         continue
# -> 2119     deserializers[name] = lambda p, proc=proc: proc.from_disk(  # type: ignore[misc]
#    2120         p, exclude=["vocab"]
#    2121     )
#    2122 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2123     # Convert to list here in case exclude is (default) tuple
#    2124     exclude = list(exclude) + ["vocab"]
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy_transformers\pipeline_component.py:416, in Transformer.from_disk(self, path, exclude)
#     409         self.model.attrs["set_transformer"](self.model, hf_model)
#     411 deserialize = {
#     412     "vocab": self.vocab.from_disk,
#     413     "cfg": lambda p: self.cfg.update(deserialize_config(p)),
#     414     "model": load_model,
#     415 }
# --> 416 util.from_disk(path, deserialize, exclude)  # type: ignore
#     417 return self
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy\util.py:1352, in from_disk(path, readers, exclude)
#    1349 for key, reader in readers.items():
#    1350     # Split to support file names like meta.json
#    1351     if key.split(".")[0] not in exclude:
# -> 1352         reader(path / key)
#    1353 return path
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy_transformers\pipeline_component.py:390, in Transformer.from_disk.<locals>.load_model(p)
#     388 try:
#     389     with open(p, "rb") as mfile:
# --> 390         self.model.from_bytes(mfile.read())
#     391 except AttributeError:
#     392     raise ValueError(Errors.E149) from None
#
# File ~\.conda\envs\sentiment\lib\site-packages\thinc\model.py:619, in Model.from_bytes(self, bytes_data)
#     617 msg = srsly.msgpack_loads(bytes_data)
#     618 msg = convert_recursive(is_xp_array, self.ops.asarray, msg)
# --> 619 return self.from_dict(msg)
#
# File ~\.conda\envs\sentiment\lib\site-packages\thinc\model.py:657, in Model.from_dict(self, msg)
#     655         node.set_param(param_name, value)
#     656     for i, shim_bytes in enumerate(msg["shims"][i]):
# --> 657         node.shims[i].from_bytes(shim_bytes)
#     658 return self
#
# File ~\.conda\envs\sentiment\lib\site-packages\spacy_transformers\layers\hf_shim.py:108, in HFShim.from_bytes(self, bytes_data)
#     105         with open(vocab_file_path, "rb") as fileh:
#     106             vocab_file_contents = fileh.read()
# --> 108 transformer = self.model_cls.from_config(config)
#     109 self._hfmodel = HFObjects(
#     110     tokenizer,
#     111     transformer,
#    (...)
#     114     SimpleFrozenDict(),
#     115 )
#     116 self._model = transformer
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\auto\auto_factory.py:410, in _BaseAutoModelClass.from_config(cls, config, **kwargs)
#     408 elif type(config) in cls._model_mapping.keys():
#     409     model_class = _get_model_class(config, cls._model_mapping)
# --> 410     return model_class._from_config(config, **kwargs)
#     412 raise ValueError(
#     413     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     414     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     415 )
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\modeling_utils.py:1077, in PreTrainedModel._from_config(cls, config, **kwargs)
#    1075         model = cls(config, **kwargs)
#    1076 else:
# -> 1077     model = cls(config, **kwargs)
#    1079 # restore default dtype if it was modified
#    1080 if dtype_orig is not None:
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\roberta\modeling_roberta.py:721, in RobertaModel.__init__(self, config, add_pooling_layer)
#     718 self.config = config
#     720 self.embeddings = RobertaEmbeddings(config)
# --> 721 self.encoder = RobertaEncoder(config)
#     723 self.pooler = RobertaPooler(config) if add_pooling_layer else None
#     725 # Initialize weights and apply final processing
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\roberta\modeling_roberta.py:475, in RobertaEncoder.__init__(self, config)
#     473 super().__init__()
#     474 self.config = config
# --> 475 self.layer = nn.ModuleList([RobertaLayer(config) for _ in range(config.num_hidden_layers)])
#     476 self.gradient_checkpointing = False
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\roberta\modeling_roberta.py:475, in <listcomp>(.0)
#     473 super().__init__()
#     474 self.config = config
# --> 475 self.layer = nn.ModuleList([RobertaLayer(config) for _ in range(config.num_hidden_layers)])
#     476 self.gradient_checkpointing = False
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\roberta\modeling_roberta.py:389, in RobertaLayer.__init__(self, config)
#     387 self.chunk_size_feed_forward = config.chunk_size_feed_forward
#     388 self.seq_len_dim = 1
# --> 389 self.attention = RobertaAttention(config)
#     390 self.is_decoder = config.is_decoder
#     391 self.add_cross_attention = config.add_cross_attention
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\roberta\modeling_roberta.py:306, in RobertaAttention.__init__(self, config, position_embedding_type)
#     304 def __init__(self, config, position_embedding_type=None):
#     305     super().__init__()
# --> 306     self.self = RobertaSelfAttention(config, position_embedding_type=position_embedding_type)
#     307     self.output = RobertaSelfOutput(config)
#     308     self.pruned_heads = set()
#
# File ~\.conda\envs\sentiment\lib\site-packages\transformers\models\roberta\modeling_roberta.py:168, in RobertaSelfAttention.__init__(self, config, position_embedding_type)
#     166 self.query = nn.Linear(config.hidden_size, self.all_head_size)
#     167 self.key = nn.Linear(config.hidden_size, self.all_head_size)
# --> 168 self.value = nn.Linear(config.hidden_size, self.all_head_size)
#     170 self.dropout = nn.Dropout(config.attention_probs_dropout_prob)
#     171 self.position_embedding_type = position_embedding_type or getattr(
#     172     config, "position_embedding_type", "absolute"
#     173 )
#
# File ~\.conda\envs\sentiment\lib\site-packages\torch\nn\modules\linear.py:101, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      99 else:
#     100     self.register_parameter('bias', None)
# --> 101 self.reset_parameters()
#
# File ~\.conda\envs\sentiment\lib\site-packages\torch\nn\modules\linear.py:107, in Linear.reset_parameters(self)
#     103 def reset_parameters(self) -> None:
#     104     # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
#     105     # uniform(-1/sqrt(in_features), 1/sqrt(in_features)). For details, see
#     106     # https://github.com/pytorch/pytorch/issues/57109
# --> 107     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#     108     if self.bias is not None:
#     109         fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# File ~\.conda\envs\sentiment\lib\site-packages\torch\nn\init.py:412, in kaiming_uniform_(tensor, a, mode, nonlinearity)
#     410 bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     411 with torch.no_grad():
# --> 412     return tensor.uniform_(-bound, bound)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('data/articles_summary.csv')

# %% [markdown]
# ### Pegasus resumen en una frase

# %%
def pegasus_summary(text):
    
    # Carga modelo
    model_name = "human-centered-summarization/financial-summarization-pegasus"
    tokenizer = PegasusTokenizer.from_pretrained(model_name)
    model = TFPegasusForConditionalGeneration.from_pretrained(model_name)
    
    try:
    # Tokenización artículos
        input_ids = tokenizer(text, return_tensors = 'tf').input_ids
        output = model.generate(
            input_ids,
            max_length=35,
            num_beams=5,
            early_stopping=True
        )
        
        # Decodificación tokens
        summarized = tokenizer.decode(output[0], skip_special_tokens=True)
        return summarized
    
    except:
        # Algunos artículos pasan el límite de tokens, los borro.
        return np.nan

df['pegasus_one_line'] = df.spacy_summary.apply(pegasus_summary)

df.dropna(inplace=True)
df.to_csv('data/articles_short_summary.csv',index=False)
# Out:
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Token indices sequence length is longer than the specified maximum sequence length for this model (1265 > 512). Running this sequence through the model will result in indexing errors
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Token indices sequence length is longer than the specified maximum sequence length for this model (700 > 512). Running this sequence through the model will result in indexing errors
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# ...
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFPegasusForConditionalGeneration.
#
# Some layers of TFPegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
df = pd.read_csv('data/articles_short_summary.csv')
df
# Out:
#             date ticker  \
# 0     2023-03-02   aapl
# 1     2023-03-02   aapl
# 2     2023-03-02   aapl
# 3     2023-03-02   aapl
# 4     2023-03-01   aapl
# ...          ...    ...
# 1054  2023-02-17   GC=F
# 1055  2023-02-17   GC=F
# 1056  2023-02-17   GC=F
# 1057  2023-02-17   GC=F
# 1058  2023-02-17   GC=F
#
#                                                                                                                                link  \
# 0                                                   https://finance.yahoo.com//news/mortgage-rates-surge-closer-to-7-170022384.html
# 1                                               https://finance.yahoo.com//news/stock-market-news-today-march-2-2023-135533324.html
# 2         https://finance.yahoo.com//news/what-the-end-of-the-great-moderation-era-means-for-investors-morning-brief-103057491.html
# 3     https://finance.yahoo.com//news/silvergate-stock-crashes-after-company-delays-annual-report-reveals-new-losses-121923800.html
# 4                                        https://finance.yahoo.com//news/stock-market-news-live-updates-march-1-2023-124448484.html
# ...                                                                                                                             ...
# 1054                                              https://finance.yahoo.com//news/natural-gas-price-forecast-natural-164415226.html
# 1055                                                    https://finance.yahoo.com//news/gold-futures-post-3rd-weekly-150517561.html
# 1056                                             https://finance.yahoo.com//news/moneyshow-market-minute-february-17-141500675.html
# 1057                                                   https://finance.yahoo.com//news/1-investors-pull-cash-classic-132804341.html
# 1058                                     https://finance.yahoo.com//news/bernstein-sec-tightening-crypto-regulations-101808714.html
#
#                                                                                                                                                    articles  \
# 0     Mortgage rates jumped higher this week, getting even closer to 7% and crushing homebuyer activity, which hit a 28-year low. The average rate on th...
# 1     Stock futures were mixed on Thursday morning as investors digested more big tech earnings and continued to weigh the implications of the recent ba...
# 2     This article first appeared in the Morning Brief. Get the Morning Brief sent directly to your inbox every Monday to Friday by 6:30 a.m. ET. Subscr...
# 3     Shares of troubled lender Silvergate (SI) fell as much as 35% Thursday morning after the company said late Wednesday it will miss a March 16 deadl...
# 4     U.S. stocks finished mostly lower Wednesday to start March as key manufacturing data offered mixed results and two Federal Reserve officials sugge...
# ...                                                                                                                                                     ...
# 1054  Natural gas markets have initially fallen during the trading session on Friday as we continue to see a lot of negativity overall. With that being ...
# 1055  By Barani Krishnan Investing.com - Gold futures posted their third weekly loss while clinging to support at the mid-$1,800 level as bulls in the s...
# 1056  Equities tumbled late yesterday, and they’re re-tumbling early today. Gold, silver, and oil are all joining in the selloff, as are Treasuries. The...
# 1057  (Adds tech flows, recent market moves) LONDON, Feb 17 (Reuters) - Investors turned more cautious in the week to Wednesday, according to data from ...
# 1058  Regulatory action against the Binance USD (BUSD) stablecoin and its issuer Paxos was specific to BUSD and cannot be extrapolated to others such as...
#
#                                                                                                                                               spacy_summary  \
# 0     “We'll find out in the next 30 days if buyers are getting used to higher rates,” Reynolds said, “or if they will stay on the sideline waiting for ...
# 1     Tesla (TSLA) shares were also in focus early Thursday, falling as much as 7% after the electric carmaker held its latest investor day on Wednesday...
# 2     "I would therefore expect greater inflation volatility, economic volatility, [and] geopolitical volatility. Whether or not that near-term pain mat...
# 3     Silvergate shares have collapsed over the last year as the company's entanglements with several crypto firms — including bankrupt exchange FTX, am...
# 4     However, Goolsbee, who will be a voter at this year’s policy-setting Federal Open Market Committee meeting, didn’t comment on monetary policy. Sin...
# ...                                                                                                                                                     ...
# 1054  Stock Markets Continue to Struggle in General, as We Have Seen a Lot of Noise S&P 500 Price Forecast – Stock Markets Breakthrough Small Triangle G...
# 1055  Gold futures posted their third weekly loss while clinging to support at the mid-$1,800 level as bulls in the space tried to discern direction ami...
# 1056  Yesterday’s faceplant was fueled by a January Producer Price Index (PPI) report showing wholesale inflation up 0.7% MOM and 6% YOY. That wasn’t go...
# 1057  BofA Global Research's weekly "Flow Show", released on Friday, showed the largest outflows from technology funds since September, the largest outf...
# 1058  The custody rule change is currently a proposal, and is favorable for bank-custodians and thus positive for crypto custodians such as Anchorage Di...
#
#                                                                                                                     pegasus_one_line  \
# 0                                            Real estate broker sees fewer buyers this year. Condo rates hit a 28-year low this week
# 1                 Salesforce beats on earnings, raises share buyback plan. Tesla shares fall as much as 7% in early Thursday trading
# 2       Sonders sees near-term volatility as key to long-term success. Schwab strategist sees volatility as key to long-term success
# 3                                                        Here is a guide to the key events in the crypto world in the past 24 hours.
# 4                   U.S. vaccine maker leans toward fiscal-hiking campaign. Goolsbee doesn’t comment on Fed’s forward-guidance path.
# ...                                                                                                                              ...
# 1054                                                                             Natural gas markets continue to see lack of demand.
# 1055                 bulls try to discern direction amid calls for hikes. U.S. wholesale prices rose most in seven months in January
# 1056                                                                       Wholesale inflation up 0.7% in March vs est. rise of 0.6%
# 1057                                                                                Emerging market funds see outflows for 14th week
# 1058  Bank-custodians should have custody rights, analysts say. Sharp price affected by short covering, higher moves: Morgan Stanley
#
#                                                  sentiment
# 0     [{'label': 'Negative', 'score': 0.8755406737327576}]
# 1     [{'label': 'Positive', 'score': 0.9999980926513672}]
# 2     [{'label': 'Positive', 'score': 0.9999901056289673}]
# 3      [{'label': 'Neutral', 'score': 0.9999940395355225}]
# 4      [{'label': 'Neutral', 'score': 0.9999891519546509}]
# ...                                                    ...
# 1054   [{'label': 'Negative', 'score': 0.999996542930603}]
# 1055    [{'label': 'Neutral', 'score': 0.984032928943634}]
# 1056   [{'label': 'Neutral', 'score': 0.7434573769569397}]
# 1057   [{'label': 'Neutral', 'score': 0.9979149699211121}]
# 1058   [{'label': 'Neutral', 'score': 0.9999790191650391}]
#
# [1059 rows x 7 columns]

# %% [markdown]
# ### Aplico FinBERT para obtener los labels de sentimiento de cada modelo, y asigno 1 a artículos positivos, -1 a negativos y 0 a neutros:
# EJ: [{'label': 'Neutral', 'score': 0.9979149699211121}]	 -> 0

# %%
def sentiment(short_sum):
    
    finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
    tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')    
    nlp = pipeline("sentiment-analysis", model=finbert, tokenizer=tokenizer)
    
    try:
        res = nlp(short_sum)
        
    except:
        res = 'ERROR'
    
    return res

df['sentiment'] = df.pegasus_one_line.apply(sentiment)

# Asigno 1 a artículos positivos, -1 a negativos y 0 a neutros.

def label(sentiment):
    
    if 'Negative' in sentiment:
        return -1
    elif 'Positive' in sentiment:
        return 1
    elif 'Neutral' in sentiment:
        return 0

df['sentiment'] = df.sentiment.apply(label)

df.to_csv('data/final_data.csv',index=False)

# %%
df
# Out:
#             date ticker  \
# 0     2023-03-02   aapl
# 1     2023-03-02   aapl
# 2     2023-03-02   aapl
# 3     2023-03-02   aapl
# 4     2023-03-01   aapl
# ...          ...    ...
# 1054  2023-02-17   GC=F
# 1055  2023-02-17   GC=F
# 1056  2023-02-17   GC=F
# 1057  2023-02-17   GC=F
# 1058  2023-02-17   GC=F
#
#                                                                                                                                link  \
# 0                                                   https://finance.yahoo.com//news/mortgage-rates-surge-closer-to-7-170022384.html
# 1                                               https://finance.yahoo.com//news/stock-market-news-today-march-2-2023-135533324.html
# 2         https://finance.yahoo.com//news/what-the-end-of-the-great-moderation-era-means-for-investors-morning-brief-103057491.html
# 3     https://finance.yahoo.com//news/silvergate-stock-crashes-after-company-delays-annual-report-reveals-new-losses-121923800.html
# 4                                        https://finance.yahoo.com//news/stock-market-news-live-updates-march-1-2023-124448484.html
# ...                                                                                                                             ...
# 1054                                              https://finance.yahoo.com//news/natural-gas-price-forecast-natural-164415226.html
# 1055                                                    https://finance.yahoo.com//news/gold-futures-post-3rd-weekly-150517561.html
# 1056                                             https://finance.yahoo.com//news/moneyshow-market-minute-february-17-141500675.html
# 1057                                                   https://finance.yahoo.com//news/1-investors-pull-cash-classic-132804341.html
# 1058                                     https://finance.yahoo.com//news/bernstein-sec-tightening-crypto-regulations-101808714.html
#
#                                                                                                                                                    articles  \
# 0     Mortgage rates jumped higher this week, getting even closer to 7% and crushing homebuyer activity, which hit a 28-year low. The average rate on th...
# 1     Stock futures were mixed on Thursday morning as investors digested more big tech earnings and continued to weigh the implications of the recent ba...
# 2     This article first appeared in the Morning Brief. Get the Morning Brief sent directly to your inbox every Monday to Friday by 6:30 a.m. ET. Subscr...
# 3     Shares of troubled lender Silvergate (SI) fell as much as 35% Thursday morning after the company said late Wednesday it will miss a March 16 deadl...
# 4     U.S. stocks finished mostly lower Wednesday to start March as key manufacturing data offered mixed results and two Federal Reserve officials sugge...
# ...                                                                                                                                                     ...
# 1054  Natural gas markets have initially fallen during the trading session on Friday as we continue to see a lot of negativity overall. With that being ...
# 1055  By Barani Krishnan Investing.com - Gold futures posted their third weekly loss while clinging to support at the mid-$1,800 level as bulls in the s...
# 1056  Equities tumbled late yesterday, and they’re re-tumbling early today. Gold, silver, and oil are all joining in the selloff, as are Treasuries. The...
# 1057  (Adds tech flows, recent market moves) LONDON, Feb 17 (Reuters) - Investors turned more cautious in the week to Wednesday, according to data from ...
# 1058  Regulatory action against the Binance USD (BUSD) stablecoin and its issuer Paxos was specific to BUSD and cannot be extrapolated to others such as...
#
#                                                                                                                                               spacy_summary  \
# 0     “We'll find out in the next 30 days if buyers are getting used to higher rates,” Reynolds said, “or if they will stay on the sideline waiting for ...
# 1     Tesla (TSLA) shares were also in focus early Thursday, falling as much as 7% after the electric carmaker held its latest investor day on Wednesday...
# 2     "I would therefore expect greater inflation volatility, economic volatility, [and] geopolitical volatility. Whether or not that near-term pain mat...
# 3     Silvergate shares have collapsed over the last year as the company's entanglements with several crypto firms — including bankrupt exchange FTX, am...
# 4     However, Goolsbee, who will be a voter at this year’s policy-setting Federal Open Market Committee meeting, didn’t comment on monetary policy. Sin...
# ...                                                                                                                                                     ...
# 1054  Stock Markets Continue to Struggle in General, as We Have Seen a Lot of Noise S&P 500 Price Forecast – Stock Markets Breakthrough Small Triangle G...
# 1055  Gold futures posted their third weekly loss while clinging to support at the mid-$1,800 level as bulls in the space tried to discern direction ami...
# 1056  Yesterday’s faceplant was fueled by a January Producer Price Index (PPI) report showing wholesale inflation up 0.7% MOM and 6% YOY. That wasn’t go...
# 1057  BofA Global Research's weekly "Flow Show", released on Friday, showed the largest outflows from technology funds since September, the largest outf...
# 1058  The custody rule change is currently a proposal, and is favorable for bank-custodians and thus positive for crypto custodians such as Anchorage Di...
#
#                                                                                                                     pegasus_one_line  \
# 0                                            Real estate broker sees fewer buyers this year. Condo rates hit a 28-year low this week
# 1                 Salesforce beats on earnings, raises share buyback plan. Tesla shares fall as much as 7% in early Thursday trading
# 2       Sonders sees near-term volatility as key to long-term success. Schwab strategist sees volatility as key to long-term success
# 3                                                        Here is a guide to the key events in the crypto world in the past 24 hours.
# 4                   U.S. vaccine maker leans toward fiscal-hiking campaign. Goolsbee doesn’t comment on Fed’s forward-guidance path.
# ...                                                                                                                              ...
# 1054                                                                             Natural gas markets continue to see lack of demand.
# 1055                 bulls try to discern direction amid calls for hikes. U.S. wholesale prices rose most in seven months in January
# 1056                                                                       Wholesale inflation up 0.7% in March vs est. rise of 0.6%
# 1057                                                                                Emerging market funds see outflows for 14th week
# 1058  Bank-custodians should have custody rights, analysts say. Sharp price affected by short covering, higher moves: Morgan Stanley
#
#       sentiment
# 0            -1
# 1             1
# 2             1
# 3             0
# 4             0
# ...         ...
# 1054         -1
# 1055          0
# 1056          0
# 1057          0
# 1058          0
#
# [1059 rows x 7 columns]
